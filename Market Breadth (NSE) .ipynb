# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # BRUH

# %%
loser_array = []
winner_array = []
lol = pd.DataFrame()

# %%
def winner_array_iterator(stock):
    winner_array.append(stock)

def loser_array_iterator(stock):
    loser_array.append(stock)

def informationGatherer(n):
    global lol,winner_array,loser_array
    df = pd.read_csv('cm{}AUG2021bhav.csv'.format(n))
    date = df['TIMESTAMP'].iloc[1]
    print(date)
    df = df.drop(['SERIES','HIGH','LOW','LAST','TIMESTAMP','ISIN','TOTTRDQTY','Unnamed: 13','TOTTRDVAL',
                  'PREVCLOSE'],axis=1)
    df['CHANGE'] = ((df['CLOSE'] - df['OPEN'])*100 / df['OPEN']).round(2)
    
    df_filtered = df[abs(df['CHANGE']) > 4.5]
#     df_filtered = df_filtered[df_filtered['TOTALTRADES'] >= 20000]
#     df_filtered = df_filtered[df_filtered['OPEN'] >= 100]
    
    winners = df_filtered[df_filtered['CHANGE']>= 4.5]
    print(winners.count().SYMBOL)
    winners = winners.sort_values('CHANGE', ascending=False)
    
    lossers = df_filtered[df_filtered['CHANGE']<= -4.5]
    print(lossers.count().SYMBOL)
    lossers = lossers.sort_values(by=['CHANGE'], ascending=True)
    

    winners['SYMBOL'].apply(winner_array_iterator)
    lossers['SYMBOL'].apply(loser_array_iterator)
    
    lol = lol.append({'id': date , 'Number of Stocks up 4.5%': winners.count().SYMBOL, 
                      'Number of Stocks down 4.5%': lossers.count().SYMBOL, 
                      'Winners Names': winner_array,
                      'Losers Names':loser_array}, ignore_index=True)
    
    loser_array = []
    winner_array = []

# %%
informationGatherer('23')

cols = lol.columns.tolist()
cols = [cols[-1]] + cols[2:0:-1] + [cols[-2]] + [cols[0]]
lol = lol[cols]

array = ['20','18','17','16','13','12','11','10','09','06','05','04','03','02']

for i in array:
    informationGatherer(i)

lol.head(50)
# Out:
# 23-AUG-2021
# 45
# 702
# 20-AUG-2021
# 55
# 195
# 18-AUG-2021
# 60
# 187
# 17-AUG-2021
# 65
# 179
# 16-AUG-2021
# 54
# 255
# 13-AUG-2021
# 68
# 148
# 12-AUG-2021
# 347
# 34
# 11-AUG-2021
# 97
# 210
# 10-AUG-2021
# 30
# 633
# 09-AUG-2021
# 67
# 266
# 06-AUG-2021
# 127
# 77
# 05-AUG-2021
# 53
# 190
# 04-AUG-2021
# 43
# 312
# 03-AUG-2021
# 87
# 106
# 02-AUG-2021
# 153
# 81
#              id  Number of Stocks up 4.5%  Number of Stocks down 4.5%  \
# 0   23-AUG-2021                      45.0                       702.0
# 1   20-AUG-2021                      55.0                       195.0
# 2   18-AUG-2021                      60.0                       187.0
# 3   17-AUG-2021                      65.0                       179.0
# 4   16-AUG-2021                      54.0                       255.0
# 5   13-AUG-2021                      68.0                       148.0
# 6   12-AUG-2021                     347.0                        34.0
# 7   11-AUG-2021                      97.0                       210.0
# 8   10-AUG-2021                      30.0                       633.0
# 9   09-AUG-2021                      67.0                       266.0
# 10  06-AUG-2021                     127.0                        77.0
# 11  05-AUG-2021                      53.0                       190.0
# 12  04-AUG-2021                      43.0                       312.0
# 13  03-AUG-2021                      87.0                       106.0
# 14  02-AUG-2021                     153.0                        81.0
#
#                                         Winners Names  \
# 0   [JIKIND, ANTGRAPHIC, BLS, NIACL, SREIBNPNCD, L...
# 1   [SECURKLOUD, ACCURACY, NTPC, SREIBNPNCD, VIDHI...
# 2   [VSTTILLERS, EIMCOELECO, PIONDIST, IDEA, TREJH...
# 3   [SREIBNPNCD, JUNIORBEES, APOLLOHOSP, KIMS, AST...
# 4   [SVPGLOB, IDFCFIRSTB, LXCHEM, BARBEQUE, GRAVIT...
# 5   [TDPOWERSYS, MRO-TEK, FILDF2GPD, SHRIRAMCIT, N...
# 6   [MARSHALL, SREIBNPNCD, HBLPOWER, ARIHANTCAP, S...
# 7   [APOLSINHOT, SPMLINFRA, HIKAL, AIROLAM, BHAGYA...
# 8   [FSC, FEL, NORBTEAEXP, FRETAIL, JHS, FLFL, DYN...
# 9   [ANMOL, KSHITIJPOL, NBIFIN, CENTEXT, PALREDTEC...
# 10  [NETF, ECLFINANCE, RAJRAYON, BASF, ACCURACY, M...
# 11  [SREIBNPNCD, RECLTD, FILDF2GP, HIKAL, IDEA, SH...
# 12  [RAJRAYON, DPWIRES, VARDHACRLC, GICHSGFIN, MAH...
# 13  [CINELINE, SARLAPOLY, ZOTA, NAHARPOLY, RML, PD...
# 14  [SREIBNPNCD, SREIBNPNCD, VADILALIND, NTPC, HIN...
#
#                                          Losers Names
# 0   [VISESHINFO, LIBAS, RSSOFTWARE, RAJRAYON, SREI...
# 1   [SREIBNPNCD, UJJIVANSFB, DIAPOWER, ICICINIFTY,...
# 2   [COFFEEDAY, TOKYOPLAST, BHAGYANGR, SWELECTES, ...
# 3   [AARVI, INFRABEES, AGROPHOS, AKASH, MANAKALUCO...
# 4   [JIKIND, CUBEXTUB, POONAWALLA, MACPOWER, LOKES...
# 5   [SREIBNPNCD, JINDALPHOT, SGIL, MINDTECK, KSCL,...
# 6   [NABARD, BANKBEES, AXISGOLD, SUULD, MELSTAR, D...
# 7   [DHANILOANS, FILDF2GP, DIAPOWER, ICICINIFTY, V...
# 8   [CMICABLES, AIROLAM, NBIFIN, STEL, SALONA, ADV...
# 9   [VISESHINFO, PVP, CUBEXTUB, RAJRAYON, ACCURACY...
# 10  [NTPC, FRETAIL, FLFL, FSC, FCONSUMER, ICICINV2...
# 11  [DIAPOWER, ICICINV20, TNTELE, JITFINFRA, MASKI...
# 12  [ALANKIT, SREIBNPNCD, SREIBNPNCD, NTPC, IDEA, ...
# 13  [NTPC, MUKANDLTD, DIAPOWER, NITINSPIN, INDSWFT...
# 14  [SRTRANSFIN, ICICINXT50, ICICINV20, INDSWFTLAB...

# %%
lol.to_csv(r'Market bredth1.csv', index = False, header=True)

# %%
len(lol['Winners Names'].iloc[1])
# Out:
# 27
